# %%
import pandas as pd

# %%
data = pd.read_csv('data.csv')

# %%
data
# Out:
#     scholar_no  roll_no student_name father_name mother_name        dob  \
# 0         1000    11000         vini        vini        vini  20-Mar-02
# 1         1004    11001      jahnavi     jahnavi     jahnavi  30-Mar-00
# 2         1008    11002       mukund      mukund      mukund  10-Apr-98
# 3         1012    11003        sahil       sahil       sahil  20-Apr-96
# 4         1016    11004        aneri       aneri       aneri  01-May-94
# 5         1020    11005      vaibhav     vaibhav     vaibhav  11-May-92
# 6         1024    11006        ketul       ketul       ketul  22-May-90
# 7         1028    11007      harshit     harshit     harshit  01-Jun-88
# 8         1032    11008          dev         dev         dev  12-Jun-86
# 9         1036    11009         deep        deep        deep  22-Jun-84
# 10        1040    11010     abitamim    abitamim    abitamim  03-Jul-82
# 11        1044    11011      lakshit     lakshit     lakshit  13-Jul-80
# ...

# %%
for student in data.values:
    marksheet_id = student[0]
    print(type(marksheet_id))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %%
average = 0.0
for student in data.values:
    print(student)

    print(average)
